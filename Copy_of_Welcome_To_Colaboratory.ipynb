# %% [markdown]
# <a href="https://colab.research.google.com/github/Brent-Liu/Brent-Liu/blob/main/Copy_of_Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv(r'/content/stock123.csv')
print (df.head())
# Out:
#    Unnamed: 0 ???????\n[?N?????]60\n[?N??]5 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                    stage_high        NaN        NaN        NaN
# 1          ??                          ???A       ???A       ???A       ????
# 2        Date                     000006.SZ  000011.SZ  000016.SZ  000019.SZ
# 3  2018/01/05                         FALSE      FALSE      FALSE      FALSE
# 4  2018/01/12                         FALSE      FALSE      FALSE      FALSE
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 997  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1        ??A       ????       ???A       ????       ????  ...          ???
# 2  000025.SZ  000030.SZ  000032.SZ  000034.SZ  000035.SZ  ...    688686.SH
# 3      FALSE      FALSE      FALSE      FALSE      FALSE  ...        FALSE
# 4      FALSE      FALSE      FALSE      FALSE      FALSE  ...        FALSE
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# df.iloc[3] select the row with date 1/5/2018, that is 5th line in origin xlsx file

# %%
df1 = df.iloc[3]

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
countNumber = 0
for index, value in df1.items():
  print(value, type(value))
  if(value=="TRUE"):
    countNumber = countNumber + 1
# Out:
# 2018/01/05 <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# TRUE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# FALSE <class 'str'>
# ...

# %%
countNumber
# Out:
# 50

# %%
from google.colab import drive
drive.mount('/content/drive')
